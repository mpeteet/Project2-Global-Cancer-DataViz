# %% [markdown]
# ### Import dependencies and load the data file

# %%
import pandas as pd
import numpy as np
import datetime as dt
import json

# %%
#movies_file = "Resources_new/movies.csv"
#movies_df = pd.read_csv(movies_file)
#movies_df.head(5)

# %%
cancer_types_file = "assets/Resources/total-cancer-deaths-by-type-clean-2017.csv"
cancertypes_df = pd.read_csv(cancer_types_file)
cancertypes_df.head(5)
# Out:
#                  entity code  year  liver   kidney  larynx  breast  thyroid  \
# 0           Afghanistan  AFG  2017    613      142     398    1296       93
# 1               Albania  ALB  2017    308       83      88     224       17
# 2               Algeria  DZA  2017    677      216     436    2233      195
# 3        American Samoa  ASM  2017      4        0       0       6        0
# 4  Andean Latin America  NaN  2017   3906      982     398    3260      528
#
#    bladder  uterine  ...  testicular  pancreatic  esophageal  nasopharynx  \
# 0      302       88  ...          23         268         862           96
# 1       43       34  ...           8         234          59           14
# 2      560      113  ...          22         903         319          475
# 3        1        2  ...           0           2           1            1
# 4      738      918  ...         123        2437         760           92
#
#    colon_and_rectum  nonmelanoma_skin  lip_and_oral_cavity  \
# ...

# %%
#risk_factors_file = "assets/Resources/share-of-cancer-deaths-attributed-to-risk-factors.csv"
#riskfactors_df = pd.read_csv(risk_factors_file)
#riskfactors_df.head(5)

# %%
cancer_pop_age_file = "data/share-of-population-with-cancer-by-age.csv"
cancerbyage_df = pd.read_csv(cancer_pop_age_file)
cancerbyage_df.head(5)
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
#
#    Prevalence - Neoplasms - Sex: Both - Age: Under 5 (Percent)  \
# 0                                           0.218791
# 1                                           0.200244
# 2                                           0.165107
# 3                                           0.155177
# 4                                           0.163521
#
#    Prevalence - Neoplasms - Sex: Both - Age: 70+ years (Percent)  \
# 0                                           1.715018
# 1                                           1.718245
# 2                                           1.725814
# 3                                           1.740286
# 4                                           1.749073
#
#    Prevalence - Neoplasms - Sex: Both - Age: 15-49 years (Percent)  \
# 0                                           0.275733
# ...

# %%
#cancer_pop_type_file = "assets/Resources/share-of-population-with-cancer-types-clean-2017.csv"
#cancerbytypes_df = pd.read_csv(cancer_pop_type_file)
#cancerbytypes_df.head(5)
# Out:
#                  entity code  year     liver    kidney    larynx    breast  \
# 0           Afghanistan  AFG  2017  0.000000  0.022039  0.013911  0.094223
# 1               Albania  ALB  2017  0.000764  0.026912  0.016119  0.180878
# 2               Algeria  DZA  2017  0.000000  0.011713  0.009039  0.159076
# 3        American Samoa  ASM  2017  0.001189  0.016651  0.007546  0.276573
# 4  Andean Latin America  NaN  2017  0.000000  0.029687  0.004017  0.118525
#
#     thyroid   bladder   uterine  ...  testicular  pancreatic  esophageal  \
# 0  0.014242  0.018554  0.007588  ...    0.000956    0.001971    0.011086
# 1  0.026987  0.013232  0.046216  ...    0.025192    0.004027    0.001848
# 2  0.040418  0.021622  0.008625  ...    0.002345    0.002051    0.001322
# 3  0.032623  0.029669  0.128925  ...    0.000849    0.003876    0.001734
# 4  0.035368  0.012871  0.038440  ...    0.006867    0.003134    0.001700
#
#    nasopharynx  colon_and_rectum  nonmelanoma_skin  lip_and_oral_cavity  \
# ...

# %%
import sqlalchemy
# from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect
from flask import Flask, jsonify
# import psycopg2
from password import password
import pandas as pd
import json
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-fe259662a81a> in <module>
#       5 from flask import Flask, jsonify
#       6 # import psycopg2
# ----> 7 from password import password
#       8 import pandas as pd
#       9 import json
#
# ModuleNotFoundError: No module named 'password'

# %%
engine = create_engine(f"postgresql://postgres:{password}@localhost:5432/cancer_db")
conn = engine.connect()
inspector = Inspect(engine)

# %%
# inspector.get_columns("by_age")

# age_data = pd.read_sql("select * from by_age", conn)
# age_data.to_dict()
        
columns = pd.read_sql("select * from by_age", conn).reset_index(drop=True)
columns = columns.to_json(orient="split", index=False)
columns
# jsonify(columns.to_dict())
# Out:
# '{"columns":["entity","code","year","all_ages","under_five","five_to_fourteen","fifteen_to_fortynine","fifty_to_sixtynine","seventy_plus"],"data":[["Afghanistan","AFG",2017,0.277,0.14,0.082,0.285,1.283,1.912],["Albania","ALB",2017,1.423,0.911,0.396,0.786,2.421,3.576],["Algeria","DZA",2017,0.534,0.127,0.104,0.394,1.327,2.126],["American Samoa","ASM",2017,0.918,0.134,0.044,0.648,2.551,4.753],["Andean Latin America",null,2017,0.603,0.146,0.041,0.302,1.683,3.528],["Andorra","AND",2017,3.436,1.139,0.404,1.448,5.785,10.304],["Angola","AGO",2017,0.225,0.113,0.019,0.211,1.1,1.723],["Antigua and Barbuda","ATG",2017,1.392,0.269,0.051,0.493,3.375,6.806],["Argentina","ARG",2017,1.326,0.227,0.088,0.693,3.004,4.685],["Armenia","ARM",2017,1.277,0.389,0.177,0.544,2.839,3.609],["Australasia",null,2017,4.415,1.096,0.454,1.461,7.574,14.829],["Australia","AUS",2017,4.387,1.08,0.436,1.419,7.561,14.92],["Austria","AUT",2017,3.471,0.801,0.402,1.251,5.687,9.03],["Azerbaijan","AZE",2017,0.762,0.446,0.21,0.46
# ...
