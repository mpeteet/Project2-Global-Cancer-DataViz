# %% [markdown]
# ### Import dependencies and load the data file

# %%
import pandas as pd
import numpy as np
import datetime as dt
import json

# %%
#movies_file = "Resources_new/movies.csv"
#movies_df = pd.read_csv(movies_file)
#movies_df.head(5)

# %%
cancer_types_file = "data/total-cancer-deaths-by-type.csv"
cancertypes_df = pd.read_csv(cancer_types_file)
cancertypes_df.head(5)
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
#
#    Deaths - Liver cancer - Sex: Both - Age: All Ages (Number)  \
# 0                                         466.253436
# 1                                         464.137333
# 2                                         471.634765
# 3                                         480.629105
# 4                                         482.489934
#
#    Deaths - Kidney cancer - Sex: Both - Age: All Ages (Number)  \
# 0                                          80.073955
# 1                                          79.617930
# 2                                          81.300485
# 3                                          84.770448
# 4                                          87.711539
#
#    Deaths - Larynx cancer - Sex: Both - Age: All Ages (Number)  \
# 0                                         290.099710
# ...

# %%
risk_factors_file = "data/share-of-cancer-deaths-attributed-to-risk-factors.csv"
riskfactors_df = pd.read_csv(risk_factors_file)
riskfactors_df.head(5)
# Out:
#                                   Entity  Code  Year  \
# 0   Adverse effects of medical treatment   NaN  2016
# 1                African trypanosomiasis   NaN  2016
# 2  Alzheimer disease and other dementias   NaN  2016
# 3                        Aortic aneurysm   NaN  2016
# 4                                 Asthma   NaN  2016
#
#    Share of deaths attributable to risk factors
# 0                                           0.0
# 1                                           0.0
# 2                                          21.4
# 3                                          44.2
# 4                                          32.3

# %%
cancer_pop_age_file = "data/share-of-population-with-cancer-by-age.csv"
cancerbyage_df = pd.read_csv(cancer_pop_age_file)
cancerbyage_df.head(5)
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
#
#    Prevalence - Neoplasms - Sex: Both - Age: Under 5 (Percent)  \
# 0                                           0.218791
# 1                                           0.200244
# 2                                           0.165107
# 3                                           0.155177
# 4                                           0.163521
#
#    Prevalence - Neoplasms - Sex: Both - Age: 70+ years (Percent)  \
# 0                                           1.715018
# 1                                           1.718245
# 2                                           1.725814
# 3                                           1.740286
# 4                                           1.749073
#
#    Prevalence - Neoplasms - Sex: Both - Age: 15-49 years (Percent)  \
# 0                                           0.275733
# ...

# %%
cancer_pop_type_file = "data/share-of-population-with-cancer-types.csv"
cancerbytypes_df = pd.read_csv(cancer_pop_type_file)
cancerbytypes_df.head(5)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-6a2c86e51172> in <module>
#       1 cancer_pop_types_file = "data/share-of-population-with-cancer-by-types.csv"
# ----> 2 cancerbytypes_df = pd.read_csv(cancer_pop_types_file)
#       3 cancerbytypes_df.head(5)
#
# ...
